# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import DataLoader
import sys
import os

sys.path.append(os.path.abspath('..'))
from src.set_up import set_up
from src.datasets.dataset import Dataset
from src.models.linear_regression import LinearRegression
import src.utility.util as utl
from src.utility.trainer import run_training, test_model

# %%
torch.manual_seed(0)
torch.set_default_dtype(torch.float64)
torch.cuda.is_available(), torch.backends.cudnn.is_available(), torch.cuda.device_count()
torch.cuda.is_available(), torch.backends.cudnn.is_available(), torch.cuda.device_count(), torch.cuda.current_device()if torch.cuda.is_available() else 'CUDA not available'

use_cuda = True
use_cuda = False if not use_cuda else torch.cuda.is_available()
device = torch.device('cuda:0' if use_cuda else 'cpu')
torch.cuda.get_device_name(device) if use_cuda else 'cpu'
print('Using device', device)
# Out:
# Using device cpu

# %% [markdown]
# ## Datasets

# %% [markdown]
# We have four datasets we want to train our models on:
# * **A1**: A1 contains samples with and without review scores / sentiment features. Each sample has an indicator whether it had reviews or not. Missing values are filled with 0. (A1 is the dataset we obtain from 02_preprocessing.ipynb).
# * **A2**: A2 contains only samples with all review scores and sentiment features.
# * **B1**: B1 contains only samples without review scores. The review scores and sentiment columns are dropped after preprocessing.
# * **B2**: B2 contains samples with and without review scores. The review scores and sentiment columns are dropped after preprocessing.
#
# All the other features are processed the same way in each set and the test set is the same for each set. See src/data/loading.py for more details.
#
# The point is that not every listing has gotten reviews, especially new ones. Therefore we want to try models that do not rely on reviews.

# %% [markdown]
# We create all our datasets, so we can load and use them for training (see **src/set_up.py**).

# %%
set_up()
# Out:
# Keeping amenities: Keeping ['baby_stuff', 'safe', 'lockonbedroomdoor', 'airconditioner', 'hairdryer', 'elevator', 'iron', 'essentials', 'coffee', 'tv', 'toaster', 'paid_parking']...
# Keeping amenities: Keeping ['baby_stuff', 'lockonbedroomdoor', 'airconditioner', 'safe', 'tv', 'elevator', 'hairdryer', 'iron', 'selfcheck-in', 'oven', 'coffee', 'essentials']...
# c:\Users\Victo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_label.py:1007: UserWarning: unknown class(es) ['boatslip', 'freeresortaccess', 'paidresortaccess', 'private_gym'] will be ignored
#   warnings.warn(
# Keeping amenities: Keeping ['safe', 'baby_stuff', 'luggagedropoffallowed', 'paid_parking', 'extrapillowsandblankets', 'hairdryer', 'essentials', 'cleaningproducts', 'elevator', 'iron', 'toaster', 'lockonbedroomdoor']...
# Keeping amenities: Keeping ['baby_stuff', 'safe', 'lockonbedroomdoor', 'airconditioner', 'hairdryer', 'elevator', 'iron', 'essentials', 'coffee', 'tv', 'toaster', 'paid_parking']...

# %% [markdown]
# ## A1

# %% [markdown]
# ### Load

# %%
# Load training and test sets
X_train_A1 = pd.read_parquet('../data/processed/A1/X_train.parquet', engine='pyarrow')
y_train_A1 = pd.read_parquet('../data/processed/A1/y_train.parquet', engine='pyarrow')
X_test_A1 = pd.read_parquet('../data/processed/A1/X_test.parquet', engine='pyarrow')
y_test_A1 = pd.read_parquet('../data/processed/A1/y_test.parquet', engine='pyarrow')

# %%
print(X_train_A1.info(), '\n')
print(X_test_A1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12170 entries, 5483 to 10222
# Data columns (total 78 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   host_since                                        12170 non-null  float64
#  1   host_response_time                                12170 non-null  float64
#  2   host_response_rate                                12170 non-null  float64
#  3   host_acceptance_rate                              12170 non-null  float64
#  4   host_is_superhost                                 12170 non-null  float64
#  5   host_listings_count                               12170 non-null  float64
#  6   host_has_profile_pic                              12170 non-null  float64
#  7   host_identity_verified                            12170 non-null  float64
#  8   neighbourhood_cleansed                            12170 non-null  float64
#  9   latitude                                          12170 non-null  float64
#  10  longitude                                         12170 non-null  float64
#  11  property_type                                     12170 non-null  float64
#  12  accommodates                                      12170 non-null  int64
#  13  bedrooms                                          12170 non-null  float64
#  14  beds                                              12170 non-null  float64
#  15  minimum_nights                                    12170 non-null  int64
#  16  maximum_nights                                    12170 non-null  int64
#  17  availability_30                                   12170 non-null  int64
#  18  availability_365                                  12170 non-null  int64
#  19  number_of_reviews                                 12170 non-null  int64
#  20  number_of_reviews_ltm                             12170 non-null  int64
#  21  review_scores_rating                              12170 non-null  float64
#  22  review_scores_accuracy                            12170 non-null  float64
#  23  review_scores_cleanliness                         12170 non-null  float64
#  24  review_scores_checkin                             12170 non-null  float64
#  25  review_scores_communication                       12170 non-null  float64
#  26  review_scores_location                            12170 non-null  float64
#  27  review_scores_value                               12170 non-null  float64
#  28  instant_bookable                                  12170 non-null  int64
#  29  reviews_per_month                                 12170 non-null  float64
#  30  median_sentiment                                  12170 non-null  float64
#  31  min_sentiment                                     12170 non-null  float64
#  32  max_sentiment                                     12170 non-null  float64
#  33  std_sentiment                                     12170 non-null  float64
#  34  sentiment_range                                   12170 non-null  float64
#  35  pct_negative                                      12170 non-null  float64
#  36  total_reviews_scored                              12170 non-null  float64
#  37  days_since_last_review                            12170 non-null  float64
#  38  review_velocity                                   12170 non-null  float64
#  39  recent_mean_sentiment                             12170 non-null  float64
#  40  sentiment_trend                                   12170 non-null  float64
#  41  mean_sentiment                                    12170 non-null  float64
#  42  has_all_review_scores                             12170 non-null  int64
#  43  room_type_entire_home_apt                         12170 non-null  float64
#  44  room_type_hotel_room                              12170 non-null  float64
#  45  room_type_private_room                            12170 non-null  float64
#  46  room_type_shared_room                             12170 non-null  float64
#  47  shared_bath                                       12170 non-null  float64
#  48  baths                                             12170 non-null  float64
#  49  neighbourhood_group_cleansed_ciutat_vella         12170 non-null  float64
#  50  neighbourhood_group_cleansed_eixample             12170 non-null  float64
#  51  neighbourhood_group_cleansed_gràcia               12170 non-null  float64
#  52  neighbourhood_group_cleansed_horta_guinardó       12170 non-null  float64
#  53  neighbourhood_group_cleansed_les_corts            12170 non-null  float64
#  54  neighbourhood_group_cleansed_nou_barris           12170 non-null  float64
#  55  neighbourhood_group_cleansed_sant_andreu          12170 non-null  float64
#  56  neighbourhood_group_cleansed_sant_martí           12170 non-null  float64
#  57  neighbourhood_group_cleansed_sants_montjuïc       12170 non-null  float64
#  58  neighbourhood_group_cleansed_sarrià_sant_gervasi  12170 non-null  float64
#  59  availability_ratio                                12170 non-null  float64
#  60  beds_per_accommodates                             12170 non-null  float64
#  61  distance_to_sagrada_familia                       12170 non-null  float64
#  62  distance_to_barceloneta                           12170 non-null  float64
#  63  distance_to_las_ramblas                           12170 non-null  float64
#  64  distance_to_camp_nou                              12170 non-null  float64
#  65  distance_to_placa_catalunya                       12170 non-null  float64
#  66  airconditioner                                    12170 non-null  int64
#  67  baby_stuff                                        12170 non-null  int64
#  68  coffee                                            12170 non-null  int64
#  69  elevator                                          12170 non-null  int64
#  70  essentials                                        12170 non-null  int64
#  71  hairdryer                                         12170 non-null  int64
#  72  iron                                              12170 non-null  int64
#  73  lockonbedroomdoor                                 12170 non-null  int64
#  74  paid_parking                                      12170 non-null  int64
#  75  safe                                              12170 non-null  int64
#  76  toaster                                           12170 non-null  int64
#  77  tv                                                12170 non-null  int64
# dtypes: float64(57), int64(21)
# memory usage: 7.3 MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 3043 entries, 1255 to 3056
# Data columns (total 78 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   host_since                                        3043 non-null   float64
#  1   host_response_time                                3043 non-null   float64
#  2   host_response_rate                                3043 non-null   float64
#  3   host_acceptance_rate                              3043 non-null   float64
#  4   host_is_superhost                                 3043 non-null   float64
#  5   host_listings_count                               3043 non-null   float64
#  6   host_has_profile_pic                              3043 non-null   float64
#  7   host_identity_verified                            3043 non-null   float64
#  8   neighbourhood_cleansed                            3043 non-null   float64
#  9   latitude                                          3043 non-null   float64
#  10  longitude                                         3043 non-null   float64
#  11  property_type                                     3043 non-null   float64
#  12  accommodates                                      3043 non-null   int64
#  13  bedrooms                                          3043 non-null   float64
#  14  beds                                              3043 non-null   float64
#  15  minimum_nights                                    3043 non-null   int64
#  16  maximum_nights                                    3043 non-null   int64
#  17  availability_30                                   3043 non-null   int64
#  18  availability_365                                  3043 non-null   int64
#  19  number_of_reviews                                 3043 non-null   int64
#  20  number_of_reviews_ltm                             3043 non-null   int64
#  21  review_scores_rating                              3043 non-null   float64
#  22  review_scores_accuracy                            3043 non-null   float64
#  23  review_scores_cleanliness                         3043 non-null   float64
#  24  review_scores_checkin                             3043 non-null   float64
#  25  review_scores_communication                       3043 non-null   float64
#  26  review_scores_location                            3043 non-null   float64
#  27  review_scores_value                               3043 non-null   float64
#  28  instant_bookable                                  3043 non-null   int64
#  29  reviews_per_month                                 3043 non-null   float64
#  30  median_sentiment                                  3043 non-null   float64
#  31  min_sentiment                                     3043 non-null   float64
#  32  max_sentiment                                     3043 non-null   float64
#  33  std_sentiment                                     3043 non-null   float64
#  34  sentiment_range                                   3043 non-null   float64
#  35  pct_negative                                      3043 non-null   float64
#  36  total_reviews_scored                              3043 non-null   float64
#  37  days_since_last_review                            3043 non-null   float64
#  38  review_velocity                                   3043 non-null   float64
#  39  recent_mean_sentiment                             3043 non-null   float64
#  40  sentiment_trend                                   3043 non-null   float64
#  41  mean_sentiment                                    3043 non-null   float64
#  42  has_all_review_scores                             3043 non-null   int64
#  43  room_type_entire_home_apt                         3043 non-null   float64
#  44  room_type_hotel_room                              3043 non-null   float64
#  45  room_type_private_room                            3043 non-null   float64
#  46  room_type_shared_room                             3043 non-null   float64
#  47  shared_bath                                       3043 non-null   float64
#  48  baths                                             3043 non-null   float64
#  49  neighbourhood_group_cleansed_ciutat_vella         3043 non-null   float64
#  50  neighbourhood_group_cleansed_eixample             3043 non-null   float64
#  51  neighbourhood_group_cleansed_gràcia               3043 non-null   float64
#  52  neighbourhood_group_cleansed_horta_guinardó       3043 non-null   float64
#  53  neighbourhood_group_cleansed_les_corts            3043 non-null   float64
#  54  neighbourhood_group_cleansed_nou_barris           3043 non-null   float64
#  55  neighbourhood_group_cleansed_sant_andreu          3043 non-null   float64
#  56  neighbourhood_group_cleansed_sant_martí           3043 non-null   float64
#  57  neighbourhood_group_cleansed_sants_montjuïc       3043 non-null   float64
#  58  neighbourhood_group_cleansed_sarrià_sant_gervasi  3043 non-null   float64
#  59  availability_ratio                                3043 non-null   float64
#  60  beds_per_accommodates                             3043 non-null   float64
#  61  distance_to_sagrada_familia                       3043 non-null   float64
#  62  distance_to_barceloneta                           3043 non-null   float64
#  63  distance_to_las_ramblas                           3043 non-null   float64
#  64  distance_to_camp_nou                              3043 non-null   float64
#  65  distance_to_placa_catalunya                       3043 non-null   float64
#  66  airconditioner                                    3043 non-null   int64
#  67  baby_stuff                                        3043 non-null   int64
#  68  coffee                                            3043 non-null   int64
#  69  elevator                                          3043 non-null   int64
#  70  essentials                                        3043 non-null   int64
#  71  hairdryer                                         3043 non-null   int64
#  72  iron                                              3043 non-null   int64
#  73  lockonbedroomdoor                                 3043 non-null   int64
#  74  paid_parking                                      3043 non-null   int64
#  75  safe                                              3043 non-null   int64
#  76  toaster                                           3043 non-null   int64
#  77  tv                                                3043 non-null   int64
# dtypes: float64(57), int64(21)
# memory usage: 1.8 MB
# None

# %% [markdown]
# Calculate mean and standard deviation of the train set.

# %%
# Calculate mean and std
mean_train_A1 = X_train_A1.mean().to_numpy()
std_train_A1 = X_train_A1.std().to_numpy()

# %% [markdown]
# Initialise Datasets.

# %%
# Init Dataset
dataset_train_A1 = Dataset(X_train_A1, y_train_A1, mean_train_A1, std_train_A1)
dataset_test_A1 = Dataset(X_test_A1, y_test_A1, mean_train_A1, std_train_A1)

# %% [markdown]
# Create train and validation sets.

# %%
# Split for validation set
size_total = len(dataset_train_A1)
size_val = int(0.1 * size_total)
size_train = size_total - size_val

dataset_train_A1, dataset_val_A1 = torch.utils.data.random_split(
    dataset_train_A1,
    [size_train, size_val]
)

# %% [markdown]
# Initialise DataLoaders.

# %%
dataloader_train_A1 = DataLoader(dataset_train_A1, batch_size=64, shuffle=True)
dataloader_val_A1 = DataLoader(dataset_val_A1, batch_size=64, shuffle=False)
dataloader_test_A1 = DataLoader(dataset_test_A1, batch_size=64, shuffle=False)

# %% [markdown]
# Specify model, optimizer and loss function.

# %%
# Hyperparameters
params_A1 = {
    'num_epochs': 10,
    'input_dim': X_train_A1.shape[1],
    'output_dim': 1,
    'lr': 0.01
}

# %%
model_A1 = LinearRegression(input_dim=params_A1['input_dim'], output_dim=params_A1['output_dim']).to(device)
optimizer_A1 = torch.optim.Adam(model_A1.parameters(), lr=params_A1['lr'])
loss_fn = torch.nn.MSELoss()

# %% [markdown]
# ### Run training

# %%
losses_train_A1, losses_val_A1 = run_training(model_A1, optimizer_A1, loss_fn, dataloader_train_A1, dataloader_val_A1, epochs=params_A1['num_epochs'], device=device)
# Out:
# 100%|██████████| 10/10 [00:11<00:00,  1.17s/it]

# %%
print(losses_train_A1, '\n')
print(losses_val_A1)
# Out:
# [16.09499309  6.73785427  2.4217054   0.80106157  0.32259012  0.2162588
#   0.19778577  0.19581902  0.19789781  0.19871956]
#
# [10.12283341  3.90135969  1.29405826  0.43976189  0.2391011   0.20733145
#   0.19978201  0.20213488  0.20299108  0.21533157]

# %%
utl.plot_losses(losses_train_A1, losses_val_A1)

# %% [markdown]
# ### Testing

# %%
predictions_A1_log, prices_A1_log, test_loss_A1_log = test_model(model_A1, loss_fn, dataloader_test_A1, device)

test_loss_A1 = np.expm1(test_loss_A1_log)
predictions_A1 = np.expm1(predictions_A1_log).flatten()
prices_A1 = np.expm1(prices_A1_log).flatten()

print('Running loss =', test_loss_A1, '\n')
# Out:
# Running loss = 0.21999418166888876

# %%
utl.show_errors(prices_A1_log, predictions_A1_log)
# Out:
# ===== TEST SET =====
# RMSE: €117.87
# MAE:  €56.35
# Median AE:  €28.37
# R²:   0.5232
#
# R² (log-scale): 0.6787

# %%
utl.plot_true_versus_predicted(prices_A1, predictions_A1)

# %% [markdown]
# ## A2

# %% [markdown]
# ### Load

# %%
# Load training sets
X_train_A2 = pd.read_parquet('../data/processed/A2/X_train.parquet', engine='pyarrow')
y_train_A2 = pd.read_parquet('../data/processed/A2/y_train.parquet', engine='pyarrow')
X_test_A2 = pd.read_parquet('../data/processed/A2/X_test.parquet', engine='pyarrow')
y_test_A2 = pd.read_parquet('../data/processed/B1/y_test.parquet', engine='pyarrow')

# %%
print(X_train_A2.info(), '\n')
print(X_test_A2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9404 entries, 5483 to 964
# Data columns (total 77 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   host_since                                        9404 non-null   float64
#  1   host_response_time                                9404 non-null   float64
#  2   host_response_rate                                9404 non-null   float64
#  3   host_acceptance_rate                              9404 non-null   float64
#  4   host_is_superhost                                 9404 non-null   float64
#  5   host_listings_count                               9404 non-null   float64
#  6   host_has_profile_pic                              9404 non-null   float64
#  7   host_identity_verified                            9404 non-null   float64
#  8   neighbourhood_cleansed                            9404 non-null   float64
#  9   latitude                                          9404 non-null   float64
#  10  longitude                                         9404 non-null   float64
#  11  property_type                                     9404 non-null   float64
#  12  accommodates                                      9404 non-null   int64
#  13  bedrooms                                          9404 non-null   float64
#  14  beds                                              9404 non-null   float64
#  15  minimum_nights                                    9404 non-null   int64
#  16  maximum_nights                                    9404 non-null   int64
#  17  availability_30                                   9404 non-null   int64
#  18  availability_365                                  9404 non-null   int64
#  19  number_of_reviews                                 9404 non-null   int64
#  20  number_of_reviews_ltm                             9404 non-null   int64
#  21  review_scores_rating                              9404 non-null   float64
#  22  review_scores_accuracy                            9404 non-null   float64
#  23  review_scores_cleanliness                         9404 non-null   float64
#  24  review_scores_checkin                             9404 non-null   float64
#  25  review_scores_communication                       9404 non-null   float64
#  26  review_scores_location                            9404 non-null   float64
#  27  review_scores_value                               9404 non-null   float64
#  28  instant_bookable                                  9404 non-null   int64
#  29  reviews_per_month                                 9404 non-null   float64
#  30  median_sentiment                                  9404 non-null   float64
#  31  min_sentiment                                     9404 non-null   float64
#  32  max_sentiment                                     9404 non-null   float64
#  33  std_sentiment                                     9404 non-null   float64
#  34  sentiment_range                                   9404 non-null   float64
#  35  pct_negative                                      9404 non-null   float64
#  36  total_reviews_scored                              9404 non-null   float64
#  37  days_since_last_review                            9404 non-null   float64
#  38  review_velocity                                   9404 non-null   float64
#  39  recent_mean_sentiment                             9404 non-null   float64
#  40  sentiment_trend                                   9404 non-null   float64
#  41  mean_sentiment                                    9404 non-null   float64
#  42  room_type_entire_home_apt                         9404 non-null   float64
#  43  room_type_hotel_room                              9404 non-null   float64
#  44  room_type_private_room                            9404 non-null   float64
#  45  room_type_shared_room                             9404 non-null   float64
#  46  shared_bath                                       9404 non-null   float64
#  47  baths                                             9404 non-null   float64
#  48  neighbourhood_group_cleansed_ciutat_vella         9404 non-null   float64
#  49  neighbourhood_group_cleansed_eixample             9404 non-null   float64
#  50  neighbourhood_group_cleansed_gràcia               9404 non-null   float64
#  51  neighbourhood_group_cleansed_horta_guinardó       9404 non-null   float64
#  52  neighbourhood_group_cleansed_les_corts            9404 non-null   float64
#  53  neighbourhood_group_cleansed_nou_barris           9404 non-null   float64
#  54  neighbourhood_group_cleansed_sant_andreu          9404 non-null   float64
#  55  neighbourhood_group_cleansed_sant_martí           9404 non-null   float64
#  56  neighbourhood_group_cleansed_sants_montjuïc       9404 non-null   float64
#  57  neighbourhood_group_cleansed_sarrià_sant_gervasi  9404 non-null   float64
#  58  availability_ratio                                9404 non-null   float64
#  59  beds_per_accommodates                             9404 non-null   float64
#  60  distance_to_sagrada_familia                       9404 non-null   float64
#  61  distance_to_barceloneta                           9404 non-null   float64
#  62  distance_to_las_ramblas                           9404 non-null   float64
#  63  distance_to_camp_nou                              9404 non-null   float64
#  64  distance_to_placa_catalunya                       9404 non-null   float64
#  65  airconditioner                                    9404 non-null   int64
#  66  baby_stuff                                        9404 non-null   int64
#  67  coffee                                            9404 non-null   int64
#  68  elevator                                          9404 non-null   int64
#  69  essentials                                        9404 non-null   int64
#  70  hairdryer                                         9404 non-null   int64
#  71  iron                                              9404 non-null   int64
#  72  lockonbedroomdoor                                 9404 non-null   int64
#  73  oven                                              9404 non-null   int64
#  74  safe                                              9404 non-null   int64
#  75  selfcheck-in                                      9404 non-null   int64
#  76  tv                                                9404 non-null   int64
# dtypes: float64(57), int64(20)
# memory usage: 5.6 MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 3043 entries, 1255 to 3056
# Data columns (total 77 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   host_since                                        3043 non-null   float64
#  1   host_response_time                                3043 non-null   float64
#  2   host_response_rate                                3043 non-null   float64
#  3   host_acceptance_rate                              3043 non-null   float64
#  4   host_is_superhost                                 3043 non-null   float64
#  5   host_listings_count                               3043 non-null   float64
#  6   host_has_profile_pic                              3043 non-null   float64
#  7   host_identity_verified                            3043 non-null   float64
#  8   neighbourhood_cleansed                            3043 non-null   float64
#  9   latitude                                          3043 non-null   float64
#  10  longitude                                         3043 non-null   float64
#  11  property_type                                     3043 non-null   float64
#  12  accommodates                                      3043 non-null   int64
#  13  bedrooms                                          3043 non-null   float64
#  14  beds                                              3043 non-null   float64
#  15  minimum_nights                                    3043 non-null   int64
#  16  maximum_nights                                    3043 non-null   int64
#  17  availability_30                                   3043 non-null   int64
#  18  availability_365                                  3043 non-null   int64
#  19  number_of_reviews                                 3043 non-null   int64
#  20  number_of_reviews_ltm                             3043 non-null   int64
#  21  review_scores_rating                              3043 non-null   float64
#  22  review_scores_accuracy                            3043 non-null   float64
#  23  review_scores_cleanliness                         3043 non-null   float64
#  24  review_scores_checkin                             3043 non-null   float64
#  25  review_scores_communication                       3043 non-null   float64
#  26  review_scores_location                            3043 non-null   float64
#  27  review_scores_value                               3043 non-null   float64
#  28  instant_bookable                                  3043 non-null   int64
#  29  reviews_per_month                                 3043 non-null   float64
#  30  median_sentiment                                  3043 non-null   float64
#  31  min_sentiment                                     3043 non-null   float64
#  32  max_sentiment                                     3043 non-null   float64
#  33  std_sentiment                                     3043 non-null   float64
#  34  sentiment_range                                   3043 non-null   float64
#  35  pct_negative                                      3043 non-null   float64
#  36  total_reviews_scored                              3043 non-null   float64
#  37  days_since_last_review                            3043 non-null   float64
#  38  review_velocity                                   3043 non-null   float64
#  39  recent_mean_sentiment                             3043 non-null   float64
#  40  sentiment_trend                                   3043 non-null   float64
#  41  mean_sentiment                                    3043 non-null   float64
#  42  room_type_entire_home_apt                         3043 non-null   float64
#  43  room_type_hotel_room                              3043 non-null   float64
#  44  room_type_private_room                            3043 non-null   float64
#  45  room_type_shared_room                             3043 non-null   float64
#  46  shared_bath                                       3043 non-null   float64
#  47  baths                                             3043 non-null   float64
#  48  neighbourhood_group_cleansed_ciutat_vella         3043 non-null   float64
#  49  neighbourhood_group_cleansed_eixample             3043 non-null   float64
#  50  neighbourhood_group_cleansed_gràcia               3043 non-null   float64
#  51  neighbourhood_group_cleansed_horta_guinardó       3043 non-null   float64
#  52  neighbourhood_group_cleansed_les_corts            3043 non-null   float64
#  53  neighbourhood_group_cleansed_nou_barris           3043 non-null   float64
#  54  neighbourhood_group_cleansed_sant_andreu          3043 non-null   float64
#  55  neighbourhood_group_cleansed_sant_martí           3043 non-null   float64
#  56  neighbourhood_group_cleansed_sants_montjuïc       3043 non-null   float64
#  57  neighbourhood_group_cleansed_sarrià_sant_gervasi  3043 non-null   float64
#  58  availability_ratio                                3043 non-null   float64
#  59  beds_per_accommodates                             3043 non-null   float64
#  60  distance_to_sagrada_familia                       3043 non-null   float64
#  61  distance_to_barceloneta                           3043 non-null   float64
#  62  distance_to_las_ramblas                           3043 non-null   float64
#  63  distance_to_camp_nou                              3043 non-null   float64
#  64  distance_to_placa_catalunya                       3043 non-null   float64
#  65  airconditioner                                    3043 non-null   int64
#  66  baby_stuff                                        3043 non-null   int64
#  67  coffee                                            3043 non-null   int64
#  68  elevator                                          3043 non-null   int64
#  69  essentials                                        3043 non-null   int64
#  70  hairdryer                                         3043 non-null   int64
#  71  iron                                              3043 non-null   int64
#  72  lockonbedroomdoor                                 3043 non-null   int64
#  73  oven                                              3043 non-null   int64
#  74  safe                                              3043 non-null   int64
#  75  selfcheck-in                                      3043 non-null   int64
#  76  tv                                                3043 non-null   int64
# dtypes: float64(57), int64(20)
# memory usage: 1.8 MB
# None

# %% [markdown]
# Calculate mean and standard deviation of the train set.

# %%
# Calculate mean and std
mean_train_A2 = X_train_A2.mean().to_numpy()
std_train_A2 = X_train_A2.std().to_numpy()

# %% [markdown]
# Initialise Datasets.

# %%
# Init Dataset
dataset_train_A2 = Dataset(X_train_A2, y_train_A2, mean_train_A2, std_train_A2)
dataset_test_A2 = Dataset(X_test_A2, y_test_A2, mean_train_A2, std_train_A2)

# %% [markdown]
# Create train and validation sets.

# %%
# Split for validation set
size_total = len(dataset_train_A2)
size_val = int(0.1 * size_total)
size_train = size_total - size_val

dataset_train_A2, dataset_val_A2 = torch.utils.data.random_split(
    dataset_train_A2,
    [size_train, size_val]
)

# %% [markdown]
# Initialise DataLoaders.

# %%
dataloader_train_A2 = torch.utils.data.DataLoader(dataset_train_A2, batch_size=64, shuffle=True)
dataloader_val_A2 = torch.utils.data.DataLoader(dataset_val_A2, batch_size=64, shuffle=False)
dataloader_test_A2 = torch.utils.data.DataLoader(dataset_test_A2, batch_size=64, shuffle=False)

# %% [markdown]
# Specify model, optimizer and loss function.

# %%
# Hyperparameters
params_A2 = {
    'num_epochs': 10,
    'input_dim': X_train_A2.shape[1],
    'output_dim': 1,
    'lr': 0.01
}

# %%
model_A2 = LinearRegression(input_dim=params_A2['input_dim'], output_dim=params_A2['output_dim']).to(device)
optimizer_A2 = torch.optim.Adam(model_A2.parameters(), lr=params_A2['lr'])
loss_fn = torch.nn.MSELoss()

# %% [markdown]
# ### Run training

# %%
losses_train_A2, losses_val_A2 = run_training(model_A2, optimizer_A2, loss_fn, dataloader_train_A2, dataloader_val_A2, epochs=params_A2['num_epochs'], device=device)
print(losses_train_A2, '\n')
print(losses_val_A2)
# Out:
# 100%|██████████| 10/10 [00:09<00:00,  1.11it/s]
# [18.04980202  9.45771309  4.55982421  2.0135071   0.849022    0.3911497
#   0.23943932  0.19522669  0.18294476  0.18397376]
#
# [12.8944003   6.54261313  2.95440226  1.23189242  0.51505026  0.26699566
#   0.19120287  0.16845269  0.16497754  0.16352433]

# %%
utl.plot_losses(losses_train_A2, losses_val_A2)

# %% [markdown]
# ### Testing

# %%
predictions_A2_log, prices_A2_log, test_loss_A2_log = test_model(model_A2, loss_fn, dataloader_test_A2, device)

test_loss_A2 = np.expm1(test_loss_A2_log)
predictions_A2 = np.expm1(predictions_A2_log).flatten()
prices_A2 = np.expm1(prices_A2_log).flatten()

print('Running loss =', test_loss_A2, '\n')
# Out:
# Running loss = 0.21520690886973828

# %%
utl.show_errors(prices_A2_log, predictions_A2_log)
# Out:
# ===== TEST SET =====
# RMSE: €118.55
# MAE:  €55.22
# Median AE:  €29.20
# R²:   0.5177
#
# R² (log-scale): 0.6849

# %%
utl.plot_true_versus_predicted(prices_A2, predictions_A2)

# %% [markdown]
# ## B1

# %% [markdown]
# ### Load

# %%
# Load training sets
X_train_B1 = pd.read_parquet('../data/processed/B1/X_train.parquet', engine='pyarrow')
y_train_B1 = pd.read_parquet('../data/processed/B1/y_train.parquet', engine='pyarrow')
X_test_B1 = pd.read_parquet('../data/processed/B1/X_test.parquet', engine='pyarrow')
y_test_B1 = pd.read_parquet('../data/processed/B1/y_test.parquet', engine='pyarrow')

# %%
print(X_train_B1.info(), '\n')
print(X_test_B1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2766 entries, 16596 to 10222
# Data columns (total 56 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   host_since                                        2766 non-null   int64
#  1   host_response_time                                2766 non-null   float64
#  2   host_response_rate                                2766 non-null   float64
#  3   host_acceptance_rate                              2766 non-null   float64
#  4   host_is_superhost                                 2766 non-null   float64
#  5   host_listings_count                               2766 non-null   float64
#  6   host_has_profile_pic                              2766 non-null   int64
#  7   host_identity_verified                            2766 non-null   int64
#  8   neighbourhood_cleansed                            2766 non-null   float64
#  9   latitude                                          2766 non-null   float64
#  10  longitude                                         2766 non-null   float64
#  11  property_type                                     2766 non-null   float64
#  12  accommodates                                      2766 non-null   int64
#  13  bedrooms                                          2766 non-null   float64
#  14  beds                                              2766 non-null   float64
#  15  minimum_nights                                    2766 non-null   int64
#  16  maximum_nights                                    2766 non-null   int64
#  17  availability_30                                   2766 non-null   int64
#  18  availability_365                                  2766 non-null   int64
#  19  number_of_reviews                                 2766 non-null   int64
#  20  number_of_reviews_ltm                             2766 non-null   int64
#  21  instant_bookable                                  2766 non-null   int64
#  22  room_type_entire_home_apt                         2766 non-null   float64
#  23  room_type_private_room                            2766 non-null   float64
#  24  room_type_shared_room                             2766 non-null   float64
#  25  shared_bath                                       2766 non-null   float64
#  26  baths                                             2766 non-null   float64
#  27  neighbourhood_group_cleansed_ciutat_vella         2766 non-null   float64
#  28  neighbourhood_group_cleansed_eixample             2766 non-null   float64
#  29  neighbourhood_group_cleansed_gràcia               2766 non-null   float64
#  30  neighbourhood_group_cleansed_horta_guinardó       2766 non-null   float64
#  31  neighbourhood_group_cleansed_les_corts            2766 non-null   float64
#  32  neighbourhood_group_cleansed_nou_barris           2766 non-null   float64
#  33  neighbourhood_group_cleansed_sant_andreu          2766 non-null   float64
#  34  neighbourhood_group_cleansed_sant_martí           2766 non-null   float64
#  35  neighbourhood_group_cleansed_sants_montjuïc       2766 non-null   float64
#  36  neighbourhood_group_cleansed_sarrià_sant_gervasi  2766 non-null   float64
#  37  availability_ratio                                2766 non-null   float64
#  38  beds_per_accommodates                             2766 non-null   float64
#  39  distance_to_sagrada_familia                       2766 non-null   float64
#  40  distance_to_barceloneta                           2766 non-null   float64
#  41  distance_to_las_ramblas                           2766 non-null   float64
#  42  distance_to_camp_nou                              2766 non-null   float64
#  43  distance_to_placa_catalunya                       2766 non-null   float64
#  44  baby_stuff                                        2766 non-null   int64
#  45  cleaningproducts                                  2766 non-null   int64
#  46  elevator                                          2766 non-null   int64
#  47  essentials                                        2766 non-null   int64
#  48  extrapillowsandblankets                           2766 non-null   int64
#  49  hairdryer                                         2766 non-null   int64
#  50  iron                                              2766 non-null   int64
#  51  lockonbedroomdoor                                 2766 non-null   int64
#  52  luggagedropoffallowed                             2766 non-null   int64
#  53  paid_parking                                      2766 non-null   int64
#  54  safe                                              2766 non-null   int64
#  55  toaster                                           2766 non-null   int64
# dtypes: float64(33), int64(23)
# memory usage: 1.2 MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 3043 entries, 1255 to 3056
# Data columns (total 56 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   host_since                                        3043 non-null   float64
#  1   host_response_time                                3043 non-null   float64
#  2   host_response_rate                                3043 non-null   float64
#  3   host_acceptance_rate                              3043 non-null   float64
#  4   host_is_superhost                                 3043 non-null   float64
#  5   host_listings_count                               3043 non-null   float64
#  6   host_has_profile_pic                              3043 non-null   float64
#  7   host_identity_verified                            3043 non-null   float64
#  8   neighbourhood_cleansed                            3043 non-null   float64
#  9   latitude                                          3043 non-null   float64
#  10  longitude                                         3043 non-null   float64
#  11  property_type                                     3043 non-null   float64
#  12  accommodates                                      3043 non-null   int64
#  13  bedrooms                                          3043 non-null   float64
#  14  beds                                              3043 non-null   float64
#  15  minimum_nights                                    3043 non-null   int64
#  16  maximum_nights                                    3043 non-null   int64
#  17  availability_30                                   3043 non-null   int64
#  18  availability_365                                  3043 non-null   int64
#  19  number_of_reviews                                 3043 non-null   int64
#  20  number_of_reviews_ltm                             3043 non-null   int64
#  21  instant_bookable                                  3043 non-null   int64
#  22  room_type_entire_home_apt                         3043 non-null   float64
#  23  room_type_private_room                            3043 non-null   float64
#  24  room_type_shared_room                             3043 non-null   float64
#  25  shared_bath                                       3043 non-null   float64
#  26  baths                                             3043 non-null   float64
#  27  neighbourhood_group_cleansed_ciutat_vella         3043 non-null   float64
#  28  neighbourhood_group_cleansed_eixample             3043 non-null   float64
#  29  neighbourhood_group_cleansed_gràcia               3043 non-null   float64
#  30  neighbourhood_group_cleansed_horta_guinardó       3043 non-null   float64
#  31  neighbourhood_group_cleansed_les_corts            3043 non-null   float64
#  32  neighbourhood_group_cleansed_nou_barris           3043 non-null   float64
#  33  neighbourhood_group_cleansed_sant_andreu          3043 non-null   float64
#  34  neighbourhood_group_cleansed_sant_martí           3043 non-null   float64
#  35  neighbourhood_group_cleansed_sants_montjuïc       3043 non-null   float64
#  36  neighbourhood_group_cleansed_sarrià_sant_gervasi  3043 non-null   float64
#  37  availability_ratio                                3043 non-null   float64
#  38  beds_per_accommodates                             3043 non-null   float64
#  39  distance_to_sagrada_familia                       3043 non-null   float64
#  40  distance_to_barceloneta                           3043 non-null   float64
#  41  distance_to_las_ramblas                           3043 non-null   float64
#  42  distance_to_camp_nou                              3043 non-null   float64
#  43  distance_to_placa_catalunya                       3043 non-null   float64
#  44  baby_stuff                                        3043 non-null   int64
#  45  cleaningproducts                                  3043 non-null   int64
#  46  elevator                                          3043 non-null   int64
#  47  essentials                                        3043 non-null   int64
#  48  extrapillowsandblankets                           3043 non-null   int64
#  49  hairdryer                                         3043 non-null   int64
#  50  iron                                              3043 non-null   int64
#  51  lockonbedroomdoor                                 3043 non-null   int64
#  52  luggagedropoffallowed                             3043 non-null   int64
#  53  paid_parking                                      3043 non-null   int64
#  54  safe                                              3043 non-null   int64
#  55  toaster                                           3043 non-null   int64
# dtypes: float64(36), int64(20)
# memory usage: 1.3 MB
# None

# %% [markdown]
# Calculate mean and standard deviation of the train set.

# %%
# Calculate mean and std
mean_train_B1 = X_train_B1.mean().to_numpy()
std_train_B1 = X_train_B1.std().to_numpy()

# %% [markdown]
# Initialise Datasets.

# %%
# Init Dataset
dataset_train_B1 = Dataset(X_train_B1, y_train_B1, mean_train_B1, std_train_B1)
dataset_test_B1 = Dataset(X_test_B1, y_test_B1, mean_train_B1, std_train_B1)

# %% [markdown]
# Create train and validation sets.

# %%
# Split for validation set
size_total = len(dataset_train_B1)
size_val = int(0.1 * size_total)
size_train = size_total - size_val

dataset_train_B1, dataset_val_B1 = torch.utils.data.random_split(
    dataset_train_B1,
    [size_train, size_val]
)

# %% [markdown]
# Initialise DataLoaders.

# %%
dataloader_train_B1 = torch.utils.data.DataLoader(dataset_train_B1, batch_size=32, shuffle=True)
dataloader_val_B1 = torch.utils.data.DataLoader(dataset_val_B1, batch_size=32, shuffle=False)
dataloader_test_B1 = torch.utils.data.DataLoader(dataset_test_B1, batch_size=32, shuffle=False)

# %% [markdown]
# Specify model, optimizer and loss function.

# %%
# Hyperparameters
params_B1 = {
    'num_epochs': 20,
    'input_dim': X_train_B1.shape[1],
    'output_dim': 1,
    'lr': 0.01
}

# %%
model_B1 = LinearRegression(input_dim=params_B1['input_dim'], output_dim=params_B1['output_dim']).to(device)
optimizer_B1 = torch.optim.Adam(model_B1.parameters(), lr=params_B1['lr'])
loss_fn = torch.nn.MSELoss()

# %% [markdown]
# ### Run training

# %%
losses_train_B1, losses_val_B1 = run_training(model_B1, optimizer_B1, loss_fn, dataloader_train_B1, dataloader_val_B1, epochs=params_B1['num_epochs'], device=device)
print(losses_train_B1, '\n')
print(losses_val_B1)
# Out:
# 100%|██████████| 20/20 [00:05<00:00,  3.60it/s]
# [18.73273671 12.82319987  8.53432859  5.52089545  3.44695829  2.09468441
#   1.25070729  0.76128183  0.48683492  0.34272823  0.2706063   0.23913416
#   0.22454837  0.21953473  0.21793203  0.21754994  0.21635588  0.21594933
#   0.2182052   0.21789332]
#
# [15.64717356 10.61847864  7.17798063  4.60037978  2.8399978   1.73682895
#   1.06089483  0.67406266  0.47085092  0.34834392  0.29796211  0.27380796
#   0.25335195  0.24912976  0.25146546  0.24748924  0.24681179  0.23823879
#   0.25026061  0.25313547]

# %%
utl.plot_losses(losses_train_B1, losses_val_B1)

# %% [markdown]
# ### Testing

# %%
predictions_B1_log, prices_B1_log, test_loss_B1_log = test_model(model_B1, loss_fn, dataloader_test_B1, device)

# test_loss_B1 = np.expm1(test_loss_B1_log)
predictions_B1 = np.expm1(predictions_B1_log).flatten()
prices_B1 = np.expm1(prices_B1_log).flatten()

print('Running loss =', test_loss_B1, '\n')
# Out:
# Running loss = inf

# %%
utl.show_errors(prices_B1_log, predictions_B1_log)
# Out:
# ===== TEST SET =====
# RMSE: €41291426220495127568530656949122480734208.00
# MAE:  €766560315560724307736505928117318057984.00
# Median AE:  €121.00
# R²:   -58512156189450090904916934034190173398640257154404226007955686212399716630528.0000
#
# R² (log-scale): -10288981219401596.0000

# %%
utl.plot_true_versus_predicted(prices_B1, predictions_B1)

# %% [markdown]
# ## B2

# %% [markdown]
# ### Load

# %%
# Load training sets
X_train_B2 = pd.read_parquet('../data/processed/B2/X_train.parquet', engine='pyarrow')
y_train_B2 = pd.read_parquet('../data/processed/B2/y_train.parquet', engine='pyarrow')
X_test_B2 = pd.read_parquet('../data/processed/B2/X_test.parquet', engine='pyarrow')
y_test_B2 = pd.read_parquet('../data/processed/B2/y_test.parquet', engine='pyarrow')

# %%
print(X_train_B2.info(), '\n')
print(X_test_B2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12170 entries, 5483 to 10222
# Data columns (total 57 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   host_since                                        12170 non-null  float64
#  1   host_response_time                                12170 non-null  float64
#  2   host_response_rate                                12170 non-null  float64
#  3   host_acceptance_rate                              12170 non-null  float64
#  4   host_is_superhost                                 12170 non-null  float64
#  5   host_listings_count                               12170 non-null  float64
#  6   host_has_profile_pic                              12170 non-null  float64
#  7   host_identity_verified                            12170 non-null  float64
#  8   neighbourhood_cleansed                            12170 non-null  float64
#  9   latitude                                          12170 non-null  float64
#  10  longitude                                         12170 non-null  float64
#  11  property_type                                     12170 non-null  float64
#  12  accommodates                                      12170 non-null  int64
#  13  bedrooms                                          12170 non-null  float64
#  14  beds                                              12170 non-null  float64
#  15  minimum_nights                                    12170 non-null  int64
#  16  maximum_nights                                    12170 non-null  int64
#  17  availability_30                                   12170 non-null  int64
#  18  availability_365                                  12170 non-null  int64
#  19  number_of_reviews                                 12170 non-null  int64
#  20  number_of_reviews_ltm                             12170 non-null  int64
#  21  instant_bookable                                  12170 non-null  int64
#  22  room_type_entire_home_apt                         12170 non-null  float64
#  23  room_type_hotel_room                              12170 non-null  float64
#  24  room_type_private_room                            12170 non-null  float64
#  25  room_type_shared_room                             12170 non-null  float64
#  26  shared_bath                                       12170 non-null  float64
#  27  baths                                             12170 non-null  float64
#  28  neighbourhood_group_cleansed_ciutat_vella         12170 non-null  float64
#  29  neighbourhood_group_cleansed_eixample             12170 non-null  float64
#  30  neighbourhood_group_cleansed_gràcia               12170 non-null  float64
#  31  neighbourhood_group_cleansed_horta_guinardó       12170 non-null  float64
#  32  neighbourhood_group_cleansed_les_corts            12170 non-null  float64
#  33  neighbourhood_group_cleansed_nou_barris           12170 non-null  float64
#  34  neighbourhood_group_cleansed_sant_andreu          12170 non-null  float64
#  35  neighbourhood_group_cleansed_sant_martí           12170 non-null  float64
#  36  neighbourhood_group_cleansed_sants_montjuïc       12170 non-null  float64
#  37  neighbourhood_group_cleansed_sarrià_sant_gervasi  12170 non-null  float64
#  38  availability_ratio                                12170 non-null  float64
#  39  beds_per_accommodates                             12170 non-null  float64
#  40  distance_to_sagrada_familia                       12170 non-null  float64
#  41  distance_to_barceloneta                           12170 non-null  float64
#  42  distance_to_las_ramblas                           12170 non-null  float64
#  43  distance_to_camp_nou                              12170 non-null  float64
#  44  distance_to_placa_catalunya                       12170 non-null  float64
#  45  airconditioner                                    12170 non-null  int64
#  46  baby_stuff                                        12170 non-null  int64
#  47  coffee                                            12170 non-null  int64
#  48  elevator                                          12170 non-null  int64
#  49  essentials                                        12170 non-null  int64
#  50  hairdryer                                         12170 non-null  int64
#  51  iron                                              12170 non-null  int64
#  52  lockonbedroomdoor                                 12170 non-null  int64
#  53  paid_parking                                      12170 non-null  int64
#  54  safe                                              12170 non-null  int64
#  55  toaster                                           12170 non-null  int64
#  56  tv                                                12170 non-null  int64
# dtypes: float64(37), int64(20)
# memory usage: 5.4 MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 3043 entries, 1255 to 3056
# Data columns (total 57 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   host_since                                        3043 non-null   float64
#  1   host_response_time                                3043 non-null   float64
#  2   host_response_rate                                3043 non-null   float64
#  3   host_acceptance_rate                              3043 non-null   float64
#  4   host_is_superhost                                 3043 non-null   float64
#  5   host_listings_count                               3043 non-null   float64
#  6   host_has_profile_pic                              3043 non-null   float64
#  7   host_identity_verified                            3043 non-null   float64
#  8   neighbourhood_cleansed                            3043 non-null   float64
#  9   latitude                                          3043 non-null   float64
#  10  longitude                                         3043 non-null   float64
#  11  property_type                                     3043 non-null   float64
#  12  accommodates                                      3043 non-null   int64
#  13  bedrooms                                          3043 non-null   float64
#  14  beds                                              3043 non-null   float64
#  15  minimum_nights                                    3043 non-null   int64
#  16  maximum_nights                                    3043 non-null   int64
#  17  availability_30                                   3043 non-null   int64
#  18  availability_365                                  3043 non-null   int64
#  19  number_of_reviews                                 3043 non-null   int64
#  20  number_of_reviews_ltm                             3043 non-null   int64
#  21  instant_bookable                                  3043 non-null   int64
#  22  room_type_entire_home_apt                         3043 non-null   float64
#  23  room_type_hotel_room                              3043 non-null   float64
#  24  room_type_private_room                            3043 non-null   float64
#  25  room_type_shared_room                             3043 non-null   float64
#  26  shared_bath                                       3043 non-null   float64
#  27  baths                                             3043 non-null   float64
#  28  neighbourhood_group_cleansed_ciutat_vella         3043 non-null   float64
#  29  neighbourhood_group_cleansed_eixample             3043 non-null   float64
#  30  neighbourhood_group_cleansed_gràcia               3043 non-null   float64
#  31  neighbourhood_group_cleansed_horta_guinardó       3043 non-null   float64
#  32  neighbourhood_group_cleansed_les_corts            3043 non-null   float64
#  33  neighbourhood_group_cleansed_nou_barris           3043 non-null   float64
#  34  neighbourhood_group_cleansed_sant_andreu          3043 non-null   float64
#  35  neighbourhood_group_cleansed_sant_martí           3043 non-null   float64
#  36  neighbourhood_group_cleansed_sants_montjuïc       3043 non-null   float64
#  37  neighbourhood_group_cleansed_sarrià_sant_gervasi  3043 non-null   float64
#  38  availability_ratio                                3043 non-null   float64
#  39  beds_per_accommodates                             3043 non-null   float64
#  40  distance_to_sagrada_familia                       3043 non-null   float64
#  41  distance_to_barceloneta                           3043 non-null   float64
#  42  distance_to_las_ramblas                           3043 non-null   float64
#  43  distance_to_camp_nou                              3043 non-null   float64
#  44  distance_to_placa_catalunya                       3043 non-null   float64
#  45  airconditioner                                    3043 non-null   int64
#  46  baby_stuff                                        3043 non-null   int64
#  47  coffee                                            3043 non-null   int64
#  48  elevator                                          3043 non-null   int64
#  49  essentials                                        3043 non-null   int64
#  50  hairdryer                                         3043 non-null   int64
#  51  iron                                              3043 non-null   int64
#  52  lockonbedroomdoor                                 3043 non-null   int64
#  53  paid_parking                                      3043 non-null   int64
#  54  safe                                              3043 non-null   int64
#  55  toaster                                           3043 non-null   int64
#  56  tv                                                3043 non-null   int64
# dtypes: float64(37), int64(20)
# memory usage: 1.3 MB
# None

# %% [markdown]
# Calculate mean and standard deviation of the train set.

# %%
# Calculate mean and std
mean_train_B2 = X_train_B2.mean().to_numpy()
std_train_B2 = X_train_B2.std().to_numpy()

# %% [markdown]
# Initialise Datasets.

# %%
# Init Dataset
dataset_train_B2 = Dataset(X_train_B2, y_train_B2, mean_train_B2, std_train_B2)
dataset_test_B2 = Dataset(X_test_B2, y_test_B2, mean_train_B2, std_train_B2)

# %% [markdown]
# Create train and validation sets.

# %%
# Split for validation set
size_total = len(dataset_train_B2)
size_val = int(0.1 * size_total)
size_train = size_total - size_val

dataset_train_B2, dataset_val_B2 = torch.utils.data.random_split(
    dataset_train_B2,
    [size_train, size_val]
)

# %% [markdown]
# Initialise DataLoaders.

# %%
dataloader_train_B2 = torch.utils.data.DataLoader(dataset_train_B2, batch_size=64, shuffle=True)
dataloader_val_B2 = torch.utils.data.DataLoader(dataset_val_B2, batch_size=64, shuffle=False)
dataloader_test_B2 = torch.utils.data.DataLoader(dataset_test_B2, batch_size=64, shuffle=False)

# %% [markdown]
# Specify model, optimizer and loss function.

# %%
# Hyperparameters
params_B2 = {
    'num_epochs': 10,
    'input_dim': X_train_B2.shape[1],
    'output_dim': 1,
    'lr': 0.01
}

# %%
model_B2 = LinearRegression(input_dim=params_B2['input_dim'], output_dim=params_B2['output_dim']).to(device)
optimizer_B2 = torch.optim.Adam(model_B2.parameters(), lr=params_B2['lr'])
loss_fn = torch.nn.MSELoss()

# %% [markdown]
# ### Run training

# %%
losses_train_B2, losses_val_B2 = run_training(model_B2, optimizer_B2, loss_fn, dataloader_train_B2, dataloader_val_B2, epochs=params_B2['num_epochs'], device=device)
print(losses_train_B2, '\n')
print(losses_val_B2)
# Out:
# 100%|██████████| 10/10 [00:11<00:00,  1.18s/it]
# [16.33983412  6.90559841  2.5069049   0.83530661  0.33126471  0.21777142
#   0.19851519  0.1951459   0.19669971  0.20040613]
#
# [10.78900965  4.16211924  1.45182958  0.53654544  0.28657686  0.23593444
#   0.22838479  0.22927151  0.22708781  0.22322579]

# %%
utl.plot_losses(losses_train_B2, losses_val_B2)

# %% [markdown]
# ### Testing

# %%
predictions_B2_log, prices_B2_log, test_loss_B2_log = test_model(model_B2, loss_fn, dataloader_test_B2, device)

test_loss_B2 = np.expm1(test_loss_B2_log).flatten()
predictions_B2 = np.expm1(predictions_B2_log).flatten()
prices_B2 = np.expm1(prices_B2_log).flatten()

print('Running loss =', test_loss_B2, '\n')
# Out:
# Running loss = [0.23127412]

# %%
utl.show_errors(prices_B2_log, predictions_B2_log)
# Out:
# ===== TEST SET =====
# RMSE: €119.60
# MAE:  €57.62
# Median AE:  €32.10
# R²:   0.5091
#
# R² (log-scale): 0.6639

# %%
utl.plot_true_versus_predicted(prices_B2, predictions_B2)
